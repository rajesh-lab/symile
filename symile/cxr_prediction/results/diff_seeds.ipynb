# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

df = pd.read_csv("diff_seeds.csv")

df = df[df['pretrained'] == False]
# df = df[~df['weight_decay'].isin([1.0, 0.5])]

len(df)
# Out:
# 2000

# %%
col_to_keep = ['loss_fn', 'seed', 'pretrained', 'labs_model',
       'weight_decay', 'learning_rate', 'epoch',
       'run_name', 'ckpt_pt', 'wandb_path',
       'val_loss',
       'val_true_cxr_acc_at_1', 'val_true_cxr_acc_at_5', 'val_true_cxr_acc_at_10',
       'val_label_acc_at_1', 'val_label_acc_at_5', 'val_label_acc_at_10',
#        'val_label_precision_at_1', 'val_label_precision_at_5', 'val_label_precision_at_10',
       ]
df = df[col_to_keep]

# %%
idx = df.groupby(['loss_fn', 'seed'])['val_loss'].idxmin()
df.loc[idx]
# Out:
#      loss_fn  seed  pretrained labs_model  weight_decay  learning_rate  epoch  \
# 1030    clip     0       False        mlp           0.1           0.01     30
# 1127    clip     1       False        mlp           0.1           0.01     27
# 1226    clip     2       False        mlp           0.1           0.01     26
# 1328    clip     3       False        mlp           0.1           0.01     28
# 1427    clip     4       False        mlp           0.1           0.01     27
# 1529    clip     5       False        mlp           0.1           0.01     29
# 1626    clip     6       False        mlp           0.1           0.01     26
# 1728    clip     7       False        mlp           0.1           0.01     28
# 1835    clip     8       False        mlp           0.1           0.01     35
# 1935    clip     9       False        mlp           0.1           0.01     35
# 33    symile     0       False        mlp           0.1           0.01     33
# ...

# %%
df[df['loss_fn']=="symile"].sort_values(by="val_loss", ascending=True).head(1)

# %%
idx = df.groupby(['loss_fn', 'seed'])['val_true_cxr_acc_at_1'].idxmax()
df.loc[idx]
# Out:
#      loss_fn  seed  pretrained labs_model  weight_decay  learning_rate  epoch  \
# 1024    clip     0       False        mlp           0.1           0.01     24
# 1129    clip     1       False        mlp           0.1           0.01     29
# 1216    clip     2       False        mlp           0.1           0.01     16
# 1328    clip     3       False        mlp           0.1           0.01     28
# 1432    clip     4       False        mlp           0.1           0.01     32
# 1512    clip     5       False        mlp           0.1           0.01     12
# 1635    clip     6       False        mlp           0.1           0.01     35
# 1733    clip     7       False        mlp           0.1           0.01     33
# 1831    clip     8       False        mlp           0.1           0.01     31
# 1972    clip     9       False        mlp           0.1           0.01     72
# 39    symile     0       False        mlp           0.1           0.01     39
# ...

# %%
df[(df['loss_fn']=="symile")&(df['seed']==9)].sort_values(by="val_true_cxr_acc_at_1", ascending=False).head(1)
# Out:
#     loss_fn  seed  pretrained labs_model  weight_decay  learning_rate  epoch  \
# 988  symile     9       False        mlp           0.1           0.01     88
#
#                  run_name  \
# 988  20240506_161954_8355
#
#                                                                                            ckpt_pt  \
# 988  /gpfs/scratch/as16583/ckpts/cxr_prediction/20240506_161954_8355/epoch=88-val_loss=7.7888.ckpt
#
#                                            wandb_path  val_loss  \
# 988  https://wandb.ai/rajesh-lab/symile/runs/ylzu01xf  7.788838
#
#      val_true_cxr_acc_at_1  val_true_cxr_acc_at_5  val_true_cxr_acc_at_10  \
# 988                   0.16                    0.2                    0.28
#
#      val_label_acc_at_1  val_label_acc_at_5  val_label_acc_at_10
# 988                 0.2                0.32                 0.56
