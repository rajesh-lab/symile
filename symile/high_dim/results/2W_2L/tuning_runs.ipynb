# %%
import pandas as pd

# %%
df = pd.read_csv("tuning_runs.csv")

# %%
df
# Out:
#                  run_name loss_fn  \
# 0    20240420_234318_0568  symile
# 1    20240420_234318_0568  symile
# 2    20240420_234318_0568  symile
# 3    20240420_234318_0568  symile
# 4    20240420_234318_0568  symile
# ..                    ...     ...
# 211  20240423_115936_9838    clip
# 212  20240423_115936_9838    clip
# 213  20240423_115936_9838    clip
# 214  20240423_115936_9838    clip
# 215  20240423_115936_9838    clip
#
#                                                ckpt_pt  epoch   val_loss  \
# 0    /gpfs/scratch/as16583/ckpts/high_dim/20240420_...      1   0.895415
# 1    /gpfs/scratch/as16583/ckpts/high_dim/20240420_...      3   0.836875
# 2    /gpfs/scratch/as16583/ckpts/high_dim/20240420_...      5   0.814676
# 3    /gpfs/scratch/as16583/ckpts/high_dim/20240420_...      7   0.798005
# 4    /gpfs/scratch/as16583/ckpts/high_dim/20240420_...      9   0.784555
# ..                                                 ...    ...        ...
# ...

# %%
symile_df = df[df["loss_fn"] == "symile"]
clip_df = df[df["loss_fn"] == "clip"]

# %% [markdown]
# ## symile

# %%
symile_df
# Out:
#                  run_name loss_fn  \
# 0    20240420_234318_0568  symile
# 1    20240420_234318_0568  symile
# 2    20240420_234318_0568  symile
# 3    20240420_234318_0568  symile
# 4    20240420_234318_0568  symile
# ..                    ...     ...
# 103  20240421_232822_1628  symile
# 104  20240421_232822_1628  symile
# 105  20240421_232822_1628  symile
# 106  20240421_232822_1628  symile
# 107  20240421_232822_1628  symile
#
#                                                ckpt_pt  epoch  val_loss  \
# 0    /gpfs/scratch/as16583/ckpts/high_dim/20240420_...      1  0.895415
# 1    /gpfs/scratch/as16583/ckpts/high_dim/20240420_...      3  0.836875
# 2    /gpfs/scratch/as16583/ckpts/high_dim/20240420_...      5  0.814676
# 3    /gpfs/scratch/as16583/ckpts/high_dim/20240420_...      7  0.798005
# 4    /gpfs/scratch/as16583/ckpts/high_dim/20240420_...      9  0.784555
# ..                                                 ...    ...       ...
# ...

# %%
# VAL LOSS, ASCENDING TRUE
symile_df.sort_values(by="val_loss", ascending=True).head(3)
# Out:
#                  run_name loss_fn  \
# 107  20240421_232822_1628  symile
# 35   20240420_234318_7972  symile
# 71   20240420_234418_5021  symile
#
#                                                ckpt_pt  epoch  val_loss  \
# 107  /gpfs/scratch/as16583/ckpts/high_dim/20240421_...     23  0.738397
# 35   /gpfs/scratch/as16583/ckpts/high_dim/20240420_...     23  0.738397
# 71   /gpfs/scratch/as16583/ckpts/high_dim/20240420_...     23  0.738397
#
#      val_accuracy  weight_decay  learning_rate  \
# 107      0.940542        0.0010        0.00001
# 35       0.940542        0.0000        0.00001
# 71       0.940542        0.0001        0.00001
#
#                                            wandb_path
# 107  https://wandb.ai/rajesh-lab/symile/runs/ia87ymgb
# 35   https://wandb.ai/rajesh-lab/symile/runs/eheyszc4
# 71   https://wandb.ai/rajesh-lab/symile/runs/gpv9rday

# %%
# VAL ACC AT 1, ASCENDING FALSE
symile_df.sort_values(by="val_accuracy", ascending=False).head(3)
# Out:
#                  run_name loss_fn  \
# 67   20240420_234418_5021  symile
# 103  20240421_232822_1628  symile
# 31   20240420_234318_7972  symile
#
#                                                ckpt_pt  epoch  val_loss  \
# 67   /gpfs/scratch/as16583/ckpts/high_dim/20240420_...     15  0.759142
# 103  /gpfs/scratch/as16583/ckpts/high_dim/20240421_...     15  0.759142
# 31   /gpfs/scratch/as16583/ckpts/high_dim/20240420_...     15  0.759142
#
#      val_accuracy  weight_decay  learning_rate  \
# 67        0.94184        0.0001        0.00001
# 103       0.94184        0.0010        0.00001
# 31        0.94184        0.0000        0.00001
#
#                                            wandb_path
# 67   https://wandb.ai/rajesh-lab/symile/runs/gpv9rday
# 103  https://wandb.ai/rajesh-lab/symile/runs/ia87ymgb
# 31   https://wandb.ai/rajesh-lab/symile/runs/eheyszc4

# %% [markdown]
# ## clip

# %% [markdown]
# clip_df

# %%
# VAL LOSS, ASCENDING TRUE
clip_df.sort_values(by="val_loss", ascending=True).head(1)
# Out:
#                  run_name loss_fn  \
# 118  20240422_113547_4506    clip
#
#                                                ckpt_pt  epoch   val_loss  \
# 118  /gpfs/scratch/as16583/ckpts/high_dim/20240422_...     21  11.804806
#
#      val_accuracy  weight_decay  learning_rate  \
# 118      0.474352           0.0         0.0001
#
#                                            wandb_path
# 118  https://wandb.ai/rajesh-lab/symile/runs/xkg77rbv

# %%
# VAL ACC AT 1, ASCENDING FALSE
clip_df.sort_values(by="val_accuracy", ascending=False).head(3)
# Out:
#                  run_name loss_fn  \
# 214  20240423_115936_9838    clip
# 178  20240422_230041_4123    clip
# 142  20240422_113618_9164    clip
#
#                                                ckpt_pt  epoch   val_loss  \
# 214  /gpfs/scratch/as16583/ckpts/high_dim/20240423_...     21  11.827398
# 178  /gpfs/scratch/as16583/ckpts/high_dim/20240422_...     21  11.827398
# 142  /gpfs/scratch/as16583/ckpts/high_dim/20240422_...     21  11.827398
#
#      val_accuracy  weight_decay  learning_rate  \
# 214      0.475884        0.0010        0.00001
# 178      0.475884        0.0001        0.00001
# 142      0.475884        0.0000        0.00001
#
#                                            wandb_path
# 214  https://wandb.ai/rajesh-lab/symile/runs/bihyyevy
# 178  https://wandb.ai/rajesh-lab/symile/runs/plixkmla
# 142  https://wandb.ai/rajesh-lab/symile/runs/ebnfy1x5
