# %%
import pandas as pd

# %%
df = pd.read_csv('/gpfs/scratch/as16583/symile/src/datasets/symile_mimic/dataset.csv')
len(df)
# Out:
# 11622

# %%
LABEL_COLS = ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema',
              'Enlarged Cardiomediastinum', 'Fracture', 'Lung Lesion', 'Lung Opacity',
              'Pleural Effusion', 'Pleural Other', 'Pneumonia',
              'Pneumothorax','Support Devices']

# %%
count = df[(df[LABEL_COLS].sum(axis=1) == 1) &
           ((df['No Finding'].isna()) | (df['No Finding'] == 0.0))].shape[0]
count
# Out:
# 2172

# %%
(df[LABEL_COLS] == 1.0).sum()
# Out:
# Atelectasis                   3350
# Cardiomegaly                  3906
# Consolidation                  861
# Edema                         2389
# Enlarged Cardiomediastinum     586
# Fracture                       207
# Lung Lesion                    328
# Lung Opacity                  3582
# Pleural Effusion              4219
# Pleural Other                  101
# Pneumonia                     1205
# Pneumothorax                   502
# Support Devices               4669
# dtype: int64

# %%
df.columns
# Out:
# Index(['subject_id', 'hadm_id', 'admittime', 'dischtime', 'deathtime',
#        'admission_type', 'admission_location', 'discharge_location', 'race',
#        'hospital_expire_flag', 'gender', 'anchor_age', 'anchor_year', 'dod',
#        'admittime_year', 'age', 'cxr_24_72_hr', 'cxr_dicom_id', 'cxr_study_id',
#        'cxr_ViewPosition', 'cxr_ViewCodeSequence_CodeMeaning',
#        'cxr_StudyDateTime', 'cxr_path', 'study_id', 'Atelectasis',
#        'Cardiomegaly', 'Consolidation', 'Edema', 'Enlarged Cardiomediastinum',
#        'Fracture', 'Lung Lesion', 'Lung Opacity', 'No Finding',
#        'Pleural Effusion', 'Pleural Other', 'Pneumonia', 'Pneumothorax',
#        'Support Devices', 'ecg_adm', 'ecg_study_id', 'ecg_file_name',
#        'ecg_time', 'ecg_path', '51221', '51265', '50912', '50971', '51222',
#        '51301', '51249', '51279', '51250', '51248', '51277', '51006', '50983',
#        '50902', '50882', '50868', '50931', '50960', '50893', '50970', '51237',
# ...

# %%
LABEL_COLS = ['Atelectasis',
        'Cardiomegaly', 'Consolidation', 'Edema', 'Enlarged Cardiomediastinum',
       'Fracture', 'Lung Lesion', 'Lung Opacity', 'No Finding',
       'Pleural Effusion', 'Pleural Other', 'Pneumonia', 'Pneumothorax',
       'Support Devices']
