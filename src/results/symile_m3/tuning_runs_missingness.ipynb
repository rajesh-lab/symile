# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

df = pd.read_csv("/gpfs/scratch/as16583/symile/symile/high_dim/results/2W_2L_missingness/tuning_runs.csv")

# %%
len(df)
# Out:
# 216

# %%
idx = df.groupby(['loss_fn'])['val_accuracy'].idxmax()
df.loc[idx]
# Out:
#                  run_name    loss_fn  \
# 35   20240516_231001_2835  symile-50
# 143  20240517_022206_0198  symile-70
#
#                                                                                                       ckpt_pt  \
# 35     /gpfs/scratch/as16583/ckpts/high_dim/20240516_231001_2835/epoch=23-val_loss=4.4430-val_acc=0.9146.ckpt
# 143  /gpfs/data/ranganathlab/high_dim_ckpts/20240517_022206_0198/epoch=23-val_loss=5.1873-val_acc=0.6377.ckpt
#
#      epoch  val_loss  val_accuracy  weight_decay  learning_rate  \
# 35      23  4.443042      0.914550           0.0        0.00001
# 143     23  5.187293      0.637664           0.0        0.00001
#
#                                            wandb_path
# 35   https://wandb.ai/rajesh-lab/symile/runs/97vvjfhu
# 143  https://wandb.ai/rajesh-lab/symile/runs/0tra2aid
